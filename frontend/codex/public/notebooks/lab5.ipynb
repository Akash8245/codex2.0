# %% [markdown]
# # Step 1 :- Import Libraries

# %%
import nltk
from nltk.tokenize import word_tokenize
from nltk.stem import PorterStemmer,WordNetLemmatizer

# %% [markdown]
# # Step 2 :- Download Libraries

# %%
nltk.download('punkt')
nltk.download('wordnet')
nltk.download('omw-1.4')
# Out:
# [nltk_data] Downloading package punkt to /Users/joshua/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to /Users/joshua/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to /Users/joshua/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# True

# %% [markdown]
# # Step 3 :- Function for Stem Words

# %%
def Stem_words(words):
    Stemmer = PorterStemmer()
    return [Stemmer.stem(word) for word in words]

# %% [markdown]
# # Step 4 :- Function for Lemmatize Words

# %%
def Lemmatized_Words(words):
    Lemmatizer = WordNetLemmatizer()
    return [Lemmatizer.lemmatize(word,pos='n') for word in words]

# %% [markdown]
# # Step 5 :- Input Text

# %%
Text = "Cry is Crying When are you Studying" # Any Text 😂

# %%
Text
# Out:
# 'Cry is Crying When are you Studying'

# %% [markdown]
# # Step 6 :- Tokenization

# %%
Token = word_tokenize(Text)

# %%
Token
# Out:
# ['Cry', 'is', 'Crying', 'When', 'are', 'you', 'Studying']

# %% [markdown]
# # Step 7 :- Calling the Stem_Words Function

# %%
Stemmed_Words = Stem_words(Token)

# %%
Stemmed_Words
# Out:
# ['cri', 'is', 'cri', 'when', 'are', 'you', 'studi']

# %% [markdown]
# # Step 8 :- Calling the Lemmatized_Words Function

# %%
Lammatized_Words = Lemmatized_Words(Token)

# %%
Lammatized_Words
# Out:
# ['Cry', 'is', 'Crying', 'When', 'are', 'you', 'Studying']
