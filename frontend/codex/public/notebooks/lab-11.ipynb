# %%
import pandas as pd
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler

# %%
df = pd.read_csv('tripDetails.csv')

print(df.head())

features = df[['TripLength', 'TripDuration', 'Brakes']]

scaler = StandardScaler()
scaled_features = scaler.fit_transform(features)
# Out:
#    TripID  TripLength  MaxSpeed  MostFreqSpeed  TripDuration  Brakes  \
# 0       1          21        51             14            93     307
# 1       2         148       130            106           156     226
# 2       3          18        38             16           100     351
# 3       4          22        43             48            36      17
# 4       5         183       108             90           171      88
#
#    IdlingTime  Honking
# 0          27      112
# 1           5      114
# 2          26      107
# 3           4        5
# 4           5       29

# %%
kmeans = KMeans(n_clusters=3, random_state=0, n_init='auto')
kmeans.fit(scaled_features)

df['Cluster'] = kmeans.labels_

# %%
print("\nCluster Centers:\n", kmeans.cluster_centers_)

plt.scatter(df['TripLength'], df['Brakes'], c=df['Cluster'], cmap='viridis')
plt.xlabel('Trip Distance')
plt.ylabel('Brakes')
plt.title('K-Means Clustering on Trip Details')
plt.show()
# Out:
# Cluster Centers:
#  [[-0.69763244 -0.79471595 -0.6615895 ]
#  [ 1.41609384  1.20405736  0.07384016]
#  [-0.69278153  0.02901418  1.88119415]]
